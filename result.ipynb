# %%
import json
import pickle

with open('dataframes.pkl', "rb") as pkl_file:
    loaded_dataframes_dict = pickle.load(pkl_file)

# %%
all_results = []
for idx, (key, values) in enumerate(loaded_dataframes_dict.items()):
    # print(key)
    results = values.copy()
    results['cell'] = key

    all_results.append(results)

print(idx)
# Out:
# 27

# %%
import pandas as pd


pd.concat(all_results).reset_index().rename(columns={'index':'model_name'}).groupby(by='model_name').median().sort_values(by='rmse')
# Out:
# /var/folders/8y/wdvjjlbj6cnbpdh247s4gjw00000gs/T/ipykernel_94798/53981988.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.concat(all_results).reset_index().rename(columns={'index':'model_name'}).groupby(by='model_name').median().sort_values(by='rmse')
#                                                         mae           mse  \
# model_name
# lightgbm-xgboost                                3185.664167  1.612106e+07
# lightgbm                                        3405.996831  1.694970e+07
# auto_ces_model                                  3347.354182  1.984142e+07
# auto_arima_model                                3275.280005  2.010181e+07
# optimized_theta_model                           3925.086909  2.098165e+07
# ...

# %%
len([key for key, value in loaded_dataframes_dict.items() if value[value.index=='lightgbm-xgboost'].mape.values[0]<0.2])/len([key for key in loaded_dataframes_dict.keys()])
# Out:
# 0.6363636363636364
